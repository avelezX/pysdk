# %%
import sys
sys.path.append("/Users/avelezxerenity/Documents/GitHub/pysdk")
#import sys

#sys.path.append("/Users/avelezxerenity/Documents/GitHub/pysdk")
from datetime import datetime
from utilities.colombia_calendar import calendar_colombia
from utilities.date_functions import datetime_to_ql,ql_to_datetime

from utilities.colombia_calendar import calendar_colombia
from utilities.rate_conversion_functions import interest_rate_convertor
from bond_functions.tes_quant_lib_details import tes_quantlib_det
from loans_calculator.loan_structure import Loan
from swap_functions.main import full_ibr_curve_creation
import pandas as pd
import QuantLib as ql
import pandas as pd
from loans_calculator.loan_structure import Loan
from swap_functions.main import full_ibr_curve_creation


import pandas as pd
import numpy_financial as npf
import matplotlib.pyplot as plt
from collections import namedtuple
# Out:
# <QuantLib.QuantLib.SwapRateHelper; proxy of <Swig Object of type 'ext::shared_ptr< SwapRateHelper > *' at 0x1540f0ff0> >
# 2024-01-24 13:35:46,652:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# svelezsaffon@gmail.com
# 2024-01-24 13:35:49,210:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# 2024-01-24 13:35:49,574:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# 2024-01-24 13:35:50,041:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# 2024-01-24 13:35:50,640:INFO - HTTP Request: GET https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_swaps_cluster?select=%2A "HTTP/1.1 200 OK"
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# 2024-01-24 13:35:51,213:INFO - HTTP Request: GET https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_swaps_cluster?select=%2A "HTTP/1.1 200 OK"
# 2024-01-24 13:35:51,461:INFO - HTTP Request: GET https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/banrep_serie_value?select=%2A&id_serie=eq.19&order=fecha.desc&limit=1 "HTTP/1.1 200 OK"
# {'index': 0, 'tenor': 3, 'rate': 0.1181375, 'tenor_unit': 'm'}
# {'index': 1, 'tenor': 6, 'rate': 0.1144, 'tenor_unit': 'm'}
# {'index': 2, 'tenor': 9, 'rate': 0.10859999999999999, 'tenor_unit': 'm'}
# {'index': 3, 'tenor': 12, 'rate': 0.10344999999999999, 'tenor_unit': 'm'}
# {'index': 4, 'tenor': 24, 'rate': 0.082555, 'tenor_unit': 'm'}
# {'index': 5, 'tenor': 36, 'rate': 0.07585, 'tenor_unit': 'm'}
# {'index': 6, 'tenor': 48, 'rate': 0.07306, 'tenor_unit': 'm'}
# {'index': 7, 'tenor': 60, 'rate': 0.07211, 'tenor_unit': 'm'}
# {'index': 8, 'tenor': 120, 'rate': 0.073975, 'tenor_unit': 'm'}
# fwd curve tenor to calculate not in curve quotes
# [{'fecha': '2024-02-24 00:00:00', 'rate': 12.772637505391572}, {'fecha': '2024-03-24 00:00:00', 'rate': 12.358731226309416}, {'fecha': '2024-04-24 00:00:00', 'rate': 11.867837006953529}, {'fecha': '2024-05-24 00:00:00', 'rate': 11.274678568756237}, {'fecha': '2024-06-24 00:00:00', 'rate': 10.628508901092149}, {'fecha': '2024-07-24 00:00:00', 'rate': 10.04078190234634}, {'fecha': '2024-08-24 00:00:00', 'rate': 9.538116161212628}, {'fecha': '2024-09-24 00:00:00', 'rate': 9.1280388278715}, {'fecha': '2024-10-24 00:00:00', 'rate': 8.756994877495172}, {'fecha': '2024-11-24 00:00:00', 'rate': 8.379791587421348}, {'fecha': '2024-12-24 00:00:00', 'rate': 8.02819795714278}, {'fecha': '2025-01-24 00:00:00', 'rate': 7.669931050537837}, {'fecha': '2025-02-24 00:00:00', 'rate': 7.349287306017804}, {'fecha': '2025-03-24 00:00:00', 'rate': 7.074424517892197}, {'fecha': '2025-04-24 00:00:00', 'rate': 6.824877050902534}, {'fecha': '2025-05-24 00:00:00', 'rate': 6.6127821046542135}, {'fecha': '2025-06-24 00:00:00', 'rate': 6.435194278502099}, {'fecha': '2025-07-24 00:00:00', 'rate': 6.300588782251326}, {'fecha': '2025-08-24 00:00:00', 'rate': 6.200555238434258}, {'fecha': '2025-09-24 00:00:00', 'rate': 6.141160754237207}, {'fecha': '2025-10-24 00:00:00', 'rate': 6.1221190728931285}, {'fecha': '2025-11-24 00:00:00', 'rate': 6.141693437620233}, {'fecha': '2025-12-24 00:00:00', 'rate': 6.18503302825637}, {'fecha': '2026-01-24 00:00:00', 'rate': 6.243905591877841}, {'fecha': '2026-02-24 00:00:00', 'rate': 6.300617756975679}, {'fecha': '2026-03-24 00:00:00', 'rate': 6.350998975668598}, {'fecha': '2026-04-24 00:00:00', 'rate': 6.3986682603611955}, {'fecha': '2026-05-24 00:00:00', 'rate': 6.4414990234509695}, {'fecha': '2026-06-24 00:00:00', 'rate': 6.48007874121812}, {'fecha': '2026-07-24 00:00:00', 'rate': 6.51250898374458}, {'fecha': '2026-08-24 00:00:00', 'rate': 6.5408335248035465}, {'fecha': '2026-09-24 00:00:00', 'rate': 6.563482067051729}, {'fecha': '2026-10-24 00:00:00', 'rate': 6.580703845434299}, {'fecha': '2026-11-24 00:00:00', 'rate': 6.593135926627225}, {'fecha': '2026-12-24 00:00:00', 'rate': 6.60226255521037}, {'fecha': '2027-01-24 00:00:00', 'rate': 6.6122787115804105}, {'fecha': '2027-02-24 00:00:00', 'rate': 6.6250541772305604}, {'fecha': '2027-03-24 00:00:00', 'rate': 6.640925741333437}, {'fecha': '2027-04-24 00:00:00', 'rate': 6.660805715433904}, {'fecha': '2027-05-24 00:00:00', 'rate': 6.684476839539277}, {'fecha': '2027-06-24 00:00:00', 'rate': 6.712412916899124}, {'fecha': '2027-07-24 00:00:00', 'rate': 6.743283218043272}, {'fecha': '2027-08-24 00:00:00', 'rate': 6.779236313431447}, {'fecha': '2027-09-24 00:00:00', 'rate': 6.8186891364115265}, {'fecha': '2027-10-24 00:00:00', 'rate': 6.862385641156332}, {'fecha': '2027-11-24 00:00:00', 'rate': 6.910773703085082}, {'fecha': '2027-12-24 00:00:00', 'rate': 6.958836396418078}, {'fecha': '2028-01-24 00:00:00', 'rate': 7.009140146024184}, {'fecha': '2028-02-24 00:00:00', 'rate': 7.056387478800574}, {'fecha': '2028-03-24 00:00:00', 'rate': 7.1000992175669575}, {'fecha': '2028-04-24 00:00:00', 'rate': 7.1418005294897835}, {'fecha': '2028-05-24 00:00:00', 'rate': 7.1805468798146865}, {'fecha': '2028-06-24 00:00:00', 'rate': 7.216895553556046}, {'fecha': '2028-07-24 00:00:00', 'rate': 7.249060411941888}, {'fecha': '2028-08-24 00:00:00', 'rate': 7.2791045637979}, {'fecha': '2028-09-24 00:00:00', 'rate': 7.305442569026921}, {'fecha': '2028-10-24 00:00:00', 'rate': 7.328421077416913}, {'fecha': '2028-11-24 00:00:00', 'rate': 7.34854416699029}, {'fecha': '2028-12-24 00:00:00', 'rate': 7.3653507021017806}, {'fecha': '2029-01-24 00:00:00', 'rate': 7.382408885266689}, {'fecha': '2029-02-24 00:00:00', 'rate': 7.399466605321048}, {'fecha': '2029-03-24 00:00:00', 'rate': 7.4164996832352115}, {'fecha': '2029-04-24 00:00:00', 'rate': 7.4346383208727}, {'fecha': '2029-05-24 00:00:00', 'rate': 7.45335359760646}, {'fecha': '2029-06-24 00:00:00', 'rate': 7.472965276728782}, {'fecha': '2029-07-24 00:00:0 ...
# 2024-01-24 13:35:51,908:INFO - HTTP Request: DELETE https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_implicita?fecha=not.is.null "HTTP/1.1 200 OK"
# 2024-01-24 13:35:52,083:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_implicita "HTTP/1.1 201 Created"
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/avelezxerenity/Documents/GitHub/pysdk/loans_calculator/playground.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/avelezxerenity/Documents/GitHub/pysdk/loans_calculator/playground.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> from bond_functions.tes_quant_lib_details import tes_quantlib_det
#      <a href='vscode-notebook-cell:/Users/avelezxerenity/Documents/GitHub/pysdk/loans_calculator/playground.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> from loans_calculator.loan_structure import Loan
# ---> <a href='vscode-notebook-cell:/Users/avelezxerenity/Documents/GitHub/pysdk/loans_calculator/playground.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> from swap_functions.main import full_ibr_curve_creation
#      <a href='vscode-notebook-cell:/Users/avelezxerenity/Documents/GitHub/pysdk/loans_calculator/playground.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> import pandas as pd
#      <a href='vscode-notebook-cell:/Users/avelezxerenity/Documents/GitHub/pysdk/loans_calculator/playground.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> import QuantLib as ql
#
# ImportError: cannot import name 'full_ibr_curve_creation' from 'swap_functions.main' (/Users/avelezxerenity/Documents/GitHub/pysdk/swap_functions/main.py)

# %%
emision = datetime(year=2023, month=12, day=21)
maturity=datetime(year=2028,month=12,day=13)

# %%
init_date=datetime(2024, 1, 9).date()
final_date=init_date
start_date=datetime(2024, 1, 9).date()
curve=full_ibr_curve_creation(init_date,final_date,3,3)

# %%
# loan characteristics

tasa_inicio=interest_rate_convertor(0.1,'Nominal','Anual','Anual')
t_i=tasa_inicio.tasa_salida_eq('Efectiva','Anual','Anual')

# %%
loan=Loan(12,'Mensual',12*5,emision,10000,rate_type='ibr')
dates=loan.generate_cash_flow_table().to_clipboard()

#first_date=max(datetime_to_ql(emision)+ql.Period(3,ql.Days),datetime_to_ql(init_date))
#first_date

#ql_dates = [datetime_to_ql(dt)>first_date for dt in dates]



#ql_dates = pd.concat([pd.Series([first_date]), pd.Series(ql_dates)], ignore_index=True)
#ql_dates
#ql_dates

# %%
loan.generate_cash_flow_table().to_clipboard()

# %%
[curve.forwardRate(ql_dates[i], ql_dates[i + 1], ql.Actual360(), ql.Compounded).rate() for i in range(len(ql_dates) - 1)]

# %%
import QuantLib as ql
import pandas as pd

# Assuming 'dates' is your timestamp series
# Replace this with your actual data


# Convert timestamp series to QuantLib dates


# Assuming you have a QuantLib YieldTermStructure named 'curve'
# Replace this with your actual curve


# Create a new column 'forward_rates' in your DataFrame
df['forward_rates'] = [curve.forwardRate(ql_dates[i], ql_dates[i + 1], ql.Actual360(), ql.Compounded).rate() for i in range(len(ql_dates) - 1)]

# Display the updated DataFrame
print(df)

# %%
def calculate_custom_period_payment(interest_rate, num_payments, original_balance, periodicity):
    """
    Calculates the loan payment for a given periodicity.

    Parameters:
    - interest_rate (float): Annual interest rate as a percentage.
    - num_payments (int): Total number of payments.
    - original_balance (float): The loan amount.
    - periodicity (int): Number of payments per year (e.g., 12 for monthly, 6 for bimonthly, 4 for quarterly, 1 for yearly).

    Returns:
    - float: The calculated loan payment.
    """
    annual_interest_rate = interest_rate / 100
    periodic_interest_rate = annual_interest_rate / periodicity
    discount_factor = ((1 + periodic_interest_rate) ** num_payments - 1) / (periodic_interest_rate * (1 + periodic_interest_rate) ** num_payments)

    payment = original_balance / discount_factor
    return payment

# Example usage:
interest_rate = 5.0  # 5% annual interest rate
num_payments = 12  # 12 payments per year for monthly
original_balance = 10000.0  # loan amount

monthly_payment = calculate_custom_period_payment(interest_rate, num_payments, original_balance, periodicity=12)
bimonthly_payment = calculate_custom_period_payment(interest_rate, num_payments, original_balance, periodicity=6)
quarterly_payment = calculate_custom_period_payment(interest_rate, num_payments, original_balance, periodicity=4)
yearly_payment = calculate_custom_period_payment(interest_rate, num_payments, original_balance, periodicity=1)

print(f"Monthly Payment: {monthly_payment}")
print(f"Bimonthly Payment: {bimonthly_payment}")
print(f"Quarterly Payment: {quarterly_payment}")
print(f"Yearly Payment: {yearly_payment}")

# %%
import matplotlib.pyplot as plt

def calculate_custom_period_payment(interest_rate, num_payments, original_balance, periodicity):
    # (Same function as before)

# Loan details
interest_rate = 9.0  # 9% annual interest rate
num_payments = 5 * 2  # 5 years with semi-annual payments
original_balance = 10_000_000.0  # 10 million USD
periodicity = 2  # Semi-annual payments

# Calculate the semi-annual payment
semi_annual_payment = calculate_custom_period_payment(interest_rate, num_payments, original_balance, periodicity)

# Initialize lists to store cash flow components
outstanding_balance = [original_balance]
interest_paid = []
principal_paid = []

# Calculate cash flow for each period
for period in range(1, num_payments + 1):
    interest = outstanding_balance[-1] * (interest_rate / 100 / periodicity)
    principal = semi_annual_payment - interest
    outstanding_balance.append(outstanding_balance[-1] - principal)
    interest_paid.append(interest)
    principal_paid.append(principal)

# Plot the cash flow components
periods = list(range(1, num_payments + 2))

plt.plot(periods, interest_paid, label='Interest Paid')
plt.plot(periods, principal_paid, label='Principal Paid')
plt.xlabel('Period')
plt.ylabel('Amount (USD)')
plt.title('Cash Flow of Semi-Annual Loan Payments')
plt.legend()
plt.show()

# %%
import pandas as pd

# Loan details
interest_rate = 9.0  # 9% annual interest rate
num_payments = 5 * 12  # 5 years with semi-annual payments
original_balance = 10_000_000.0  # 10 million USD
periodicity = 12  # Semi-annual payments

# Calculate the semi-annual payment
semi_annual_payment = calculate_custom_period_payment(interest_rate, num_payments, original_balance, periodicity)

# Initialize lists to store cash flow components
outstanding_balance = [original_balance]
interest_paid = []
principal_paid = []

# Calculate cash flow for each period
for period in range(1, num_payments + 1):
    interest = outstanding_balance[-1] * (interest_rate / 100 / periodicity)
    principal = semi_annual_payment - interest
    outstanding_balance.append(outstanding_balance[-1] - principal)
    interest_paid.append(interest)
    principal_paid.append(principal)

# Create a DataFrame
cash_flow_df = pd.DataFrame({
    'Period': list(range(1, num_payments + 1)),  # Adjusted the range to match the number of periods
    'Outstanding Balance': outstanding_balance[:-1],  # Exclude the last value added for the next period
    'Interest Paid': interest_paid,
    'Principal Paid': principal_paid
})

# Display the DataFrame
cash_flow_df.to_clipboard()

# %%
# class Loan:
#     def __init__(self, term_years, interest_rate, original_balance, start_date):
#         self.term_years = term_years
#         self.interest_rate = interest_rate
#         self.original_balance = original_balance
#         self.start_date = start_date
#         self.start_date_ql=datetime_to_ql(self.start_date)

#     def calculate_monthly_payment(self):
#         monthly_interest_rate = self.interest_rate / 12 / 100
#         num_payments = self.term_years * 12
#         monthly_payment = npf.pmt(monthly_interest_rate, num_payments, -self.original_balance)
#         return monthly_payment

#     def generate_cash_flow_table(self):
#         monthly_payment = self.calculate_monthly_payment()
#         periods = list(range(1, self.term_years * 12 + 1))

#         interest_payment = []
#         principal_payment = []
#         ending_balance = []

#         current_balance = self.original_balance
#         for i in range(len(periods)):
#             interest_payment.append(current_balance * (self.interest_rate / 100 / 12))
#             principal_payment.append(monthly_payment - interest_payment[-1])
#             ending_balance.append(current_balance - principal_payment[-1])

#             current_balance = ending_balance[-1]

#         date_list = [self.start_date_ql + ql.Period(i, ql.Months) for i in range(len(periods))]
#         date_list = [ql_to_datetime(ql_date) for ql_date in date_list]
#         cf_data = {
#             'Date': date_list,
#             'Interest': interest_payment,
#             'Principal': principal_payment,
#             'Payment': [monthly_payment] * len(periods),
#             'Ending Balance': ending_balance,
#             'Beginning Balance': [self.original_balance] + ending_balance[:-1]
#         }

#         cf_table = pd.DataFrame(data=cf_data, index=periods)
#         cf_table = cf_table[['Date', 'Beginning Balance', 'Payment', 'Interest', 'Principal', 'Ending Balance']]

#         return cf_table
