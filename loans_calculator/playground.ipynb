# %%
import sys
sys.path.append("/Users/avelezxerenity/Documents/GitHub/pysdk")
#import sys
#sys.path.append("/Users/avelezxerenity/Documents/GitHub/pysdk")
from datetime import datetime
from utilities.colombia_calendar import calendar_colombia
from utilities.date_functions import datetime_to_ql,ql_to_datetime

from utilities.colombia_calendar import calendar_colombia
from utilities.rate_conversion_functions import interest_rate_convertor
from bond_functions.tes_quant_lib_details import tes_quantlib_det
from loans_calculator.loan_structure import Loan
from swap_functions.main import full_ibr_curve_creation
import pandas as pd
import QuantLib as ql
import pandas as pd
from loans_calculator.loan_structure import Loan
from swap_functions.main import full_ibr_curve_creation


import pandas as pd
import numpy_financial as npf
import matplotlib.pyplot as plt
from collections import namedtuple
# Out:
# <QuantLib.QuantLib.SwapRateHelper; proxy of <Swig Object of type 'ext::shared_ptr< SwapRateHelper > *' at 0x1283f1170> >
# svelezsaffon@gmail.com
# 2024-01-10 19:16:03,720:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# 2024-01-10 19:16:04,232:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# 2024-01-10 19:16:04,702:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# 2024-01-10 19:16:05,023:INFO - HTTP Request: GET https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/banrep_serie_value?select=%2A&id_serie=eq.19&order=fecha.desc&limit=1 "HTTP/1.1 200 OK"
# 2024-01-10 19:16:06,177:INFO - HTTP Request: GET https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_swaps_cluster?select=%2A "HTTP/1.1 200 OK"
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# 2024-01-10 19:16:06,789:INFO - HTTP Request: GET https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_swaps_cluster?select=%2A "HTTP/1.1 200 OK"
# {'index': 0, 'tenor': 3, 'rate': 0.12065000000000001, 'tenor_unit': 'm'}
# {'index': 1, 'tenor': 6, 'rate': 0.11865, 'tenor_unit': 'm'}
# {'index': 2, 'tenor': 9, 'rate': 0.11507500000000001, 'tenor_unit': 'm'}
# {'index': 3, 'tenor': 12, 'rate': 0.1103, 'tenor_unit': 'm'}
# {'index': 4, 'tenor': 24, 'rate': 0.08972098428571429, 'tenor_unit': 'm'}
# {'index': 5, 'tenor': 36, 'rate': 0.08221666666666666, 'tenor_unit': 'm'}
# {'index': 6, 'tenor': 48, 'rate': 0.0791, 'tenor_unit': 'm'}
# {'index': 7, 'tenor': 60, 'rate': 0.07702333333333333, 'tenor_unit': 'm'}
# {'index': 8, 'tenor': 96, 'rate': 0.07765, 'tenor_unit': 'm'}
# {'index': 9, 'tenor': 108, 'rate': 0.07765, 'tenor_unit': 'm'}
# {'index': 10, 'tenor': 120, 'rate': 0.08799241375, 'tenor_unit': 'm'}
# fwd curve tenor to calculate not in curve quotes
:00:00', 'rate': 6.9678134449811635}, {'fecha': '2028-03-24 00:00:00', 'rate': 6.959430951092971}, {'fecha': '2028-04-24 00:00:00', 'rate': 6.9707414810143975}, {'fecha': '2028-05-24 00:00:00', 'rate': 7.003369633879952}, {'fecha': '2028-06-24 00:00:00', 'rate': 7.058371952434395}, {'fecha': '2028-07-24 00:00:00', 'rate': 7.133267623603845}, {'fecha': '2028-08-24 00:00:00', 'rate': 7.233654889990193}, {'fecha': '2028-09-24 00:00:00', 'rate': 7.355689123453812}, {'fecha': '2028-10-24 00:00:00', 'rate': 7.501942135467221}, {'fecha': '2028-11-24 00:00:00', 'rate': 7.670318552794053}, {'fecha': '2028-12-24 00:00:00', 'rate': 7.8363811490015145}, {'fecha': '2029-01-24 00:00:00', 'rate': 8.01181407227103}, {'fecha': '2029-02-24 00:00:00', 'rate': 8.175596529545249}, {'fecha': '2029-03-24 00:00:00', 'rate': 8.324619843785852}, {'fecha': '2029-04-24 00:00:00', 'rate': 8.469341048117096}, {'fecha': '2029-05-24 00:00:00', 'rate': 8.603699646232288}, {'fecha': '2029-06-24 00:0 ...
# 2024-01-10 19:16:07,390:INFO - HTTP Request: DELETE https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_implicita?fecha=not.is.null "HTTP/1.1 200 OK"
# 2024-01-10 19:16:07,550:INFO - HTTP Request: POST https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_implicita "HTTP/1.1 201 Created"

# %%
emision = datetime(year=2023, month=12, day=21)
maturity=datetime(year=2028,month=12,day=13)

# %%
init_date=datetime(2024, 1, 9).date()
final_date=init_date
start_date=datetime(2024, 1, 9).date()
curve=full_ibr_curve_creation(init_date,final_date,7,8)
# Out:
# 2024-01-10 19:36:18,403:INFO - HTTP Request: GET https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_swaps_cluster?select=%2A "HTTP/1.1 200 OK"
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# /Users/avelezxerenity/Documents/GitHub/pysdk/src/xerenity/xty.py:134: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column] = pd.to_datetime(df[column])
# 2024-01-10 19:36:18,999:INFO - HTTP Request: GET https://tvpehjbqxpiswkqszwwv.supabase.co/rest/v1/ibr_swaps_cluster?select=%2A "HTTP/1.1 200 OK"
# {'index': 0, 'tenor': 1, 'rate': 0.12021666666666665, 'tenor_unit': 'm'}
# {'index': 1, 'tenor': 3, 'rate': 0.11951, 'tenor_unit': 'm'}
# {'index': 2, 'tenor': 6, 'rate': 0.11641538461538462, 'tenor_unit': 'm'}
# {'index': 3, 'tenor': 9, 'rate': 0.11132500000000001, 'tenor_unit': 'm'}
# {'index': 4, 'tenor': 12, 'rate': 0.10604, 'tenor_unit': 'm'}
# {'index': 5, 'tenor': 36, 'rate': 0.0802, 'tenor_unit': 'm'}
# {'index': 6, 'tenor': 120, 'rate': 0.0779, 'tenor_unit': 'm'}

# %%
# loan characteristics

tasa_inicio=interest_rate_convertor(0.18,'Nominal','Anual','Anual')
t_i=tasa_inicio.tasa_salida_eq('Efectiva','Anual','Anual')

# %%
loan=Loan(5*12,t_i,10000,emision)
dates=loan.generate_cash_flow_table()['Date']

first_date=max(datetime_to_ql(emision)+ql.Period(3,ql.Days),datetime_to_ql(init_date))
first_date

ql_dates = [datetime_to_ql(dt)>first_date for dt in dates]



#ql_dates = pd.concat([pd.Series([first_date]), pd.Series(ql_dates)], ignore_index=True)
#ql_dates
ql_dates
# Out:
# [False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
[curve.forwardRate(ql_dates[i], ql_dates[i + 1], ql.Actual360(), ql.Compounded).rate() for i in range(len(ql_dates) - 1)]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/t7/tjpkwm2d28sb_3ctgfhx6gr00000gp/T/ipykernel_48399/970224100.py in ?()
# ----> 1 [curve.forwardRate(ql_dates[i], ql_dates[i + 1], ql.Actual360(), ql.Compounded).rate() for i in range(len(ql_dates) - 1)]
#
# /var/folders/t7/tjpkwm2d28sb_3ctgfhx6gr00000gp/T/ipykernel_48399/970224100.py in ?(.0)
# ----> 1 [curve.forwardRate(ql_dates[i], ql_dates[i + 1], ql.Actual360(), ql.Compounded).rate() for i in range(len(ql_dates) - 1)]
#
# ~/.pyenv/versions/3.10.4/envs/xerenity_new/lib/python3.10/site-packages/QuantLib/QuantLib.py in ?(self, *args)
#    8592         r"""
#    8593         forwardRate(YieldTermStructure self, Date d1, Date d2, DayCounter arg4, Compounding arg5, Frequency f=Annual, bool extrapolate=False) -> InterestRate
#    8594         forwardRate(YieldTermStructure self, Time t1, Time t2, Compounding arg4, Frequency f=Annual, bool extrapolate=False) -> InterestRate
#    8595         """
# -> 8596         return _QuantLib.YieldTermStructure_forwardRate(self, *args)
#
# RuntimeError: negative time (-0.0555556) given

# %%
import QuantLib as ql
import pandas as pd

# Assuming 'dates' is your timestamp series
# Replace this with your actual data


# Convert timestamp series to QuantLib dates


# Assuming you have a QuantLib YieldTermStructure named 'curve'
# Replace this with your actual curve


# Create a new column 'forward_rates' in your DataFrame
df['forward_rates'] = [curve.forwardRate(ql_dates[i], ql_dates[i + 1], ql.Actual360(), ql.Compounded).rate() for i in range(len(ql_dates) - 1)]

# Display the updated DataFrame
print(df)

# %%
# class Loan:
#     def __init__(self, term_years, interest_rate, original_balance, start_date):
#         self.term_years = term_years
#         self.interest_rate = interest_rate
#         self.original_balance = original_balance
#         self.start_date = start_date
#         self.start_date_ql=datetime_to_ql(self.start_date)

#     def calculate_monthly_payment(self):
#         monthly_interest_rate = self.interest_rate / 12 / 100
#         num_payments = self.term_years * 12
#         monthly_payment = npf.pmt(monthly_interest_rate, num_payments, -self.original_balance)
#         return monthly_payment

#     def generate_cash_flow_table(self):
#         monthly_payment = self.calculate_monthly_payment()
#         periods = list(range(1, self.term_years * 12 + 1))

#         interest_payment = []
#         principal_payment = []
#         ending_balance = []

#         current_balance = self.original_balance
#         for i in range(len(periods)):
#             interest_payment.append(current_balance * (self.interest_rate / 100 / 12))
#             principal_payment.append(monthly_payment - interest_payment[-1])
#             ending_balance.append(current_balance - principal_payment[-1])

#             current_balance = ending_balance[-1]

#         date_list = [self.start_date_ql + ql.Period(i, ql.Months) for i in range(len(periods))]
#         date_list = [ql_to_datetime(ql_date) for ql_date in date_list]
#         cf_data = {
#             'Date': date_list,
#             'Interest': interest_payment,
#             'Principal': principal_payment,
#             'Payment': [monthly_payment] * len(periods),
#             'Ending Balance': ending_balance,
#             'Beginning Balance': [self.original_balance] + ending_balance[:-1]
#         }

#         cf_table = pd.DataFrame(data=cf_data, index=periods)
#         cf_table = cf_table[['Date', 'Beginning Balance', 'Payment', 'Interest', 'Principal', 'Ending Balance']]

#         return cf_table
